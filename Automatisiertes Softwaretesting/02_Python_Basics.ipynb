# %% [markdown]
# ## Python-Basics: Was Sie für TDD brauchen
#
# Um Tests zu schreiben, brauchen wir Python-Grundlagen.
# Wir lernen nur das **Nötigste** – immer im Kontext von Testing.
#
# ---
#
# ## 1. Was ist Python?
#
# Python ist eine **Programmiersprache**.
#
# **Eigenschaften:**
# - Einfach zu lesen (fast wie Englisch)
# - Keine komplizierten Sonderzeichen
# - Gut für Anfänger geeignet
# - Wird viel für Automatisierung verwendet
#
# **Beispiel für Python-Code (nur zum Anschauen):**

# %%
name = "Max"
print("Hallo " + name)

# %% [markdown]
# **Was passiert hier?**
# - Zeile 1: Eine Variable `name` bekommt den Wert `"Max"`
# - Zeile 2: Der Computer gibt aus: `Hallo Max`
#
# ---
#
# ## 2. Variablen – Daten speichern
#
# Eine **Variable** ist wie eine Box mit einem Namen, in der wir etwas speichern können.
#
# ### Beispiel: Zahlen speichern

# %%
alter = 25

# %% [markdown]
# **Erklärung:**
# - `alter` ist der Name der Variable
# - `25` ist der Wert
# - `=` bedeutet: "Speichere den Wert in der Variable"
#
# ### Beispiel: Text speichern

# %%
name = "Anna"

# %% [markdown]
# **Erklärung:**
# - Text muss in Anführungszeichen stehen: `"..."`
# - Ohne Anführungszeichen denkt Python, es wäre eine Variable
#
# ### Beispiel: Variablen verwenden

# %%
preis = 10
anzahl = 3
gesamt = preis * anzahl

# %% [markdown]
# **Was passiert hier?**
# - `preis` bekommt den Wert `10`
# - `anzahl` bekommt den Wert `3`
# - `gesamt` bekommt das Ergebnis von `10 * 3`, also `30`
#
# ---
#
# ## 3. Rechenoperationen
#
# Python kann wie ein Taschenrechner rechnen:
#
# | Operator | Bedeutung | Beispiel | Ergebnis |
# |----------|-----------|----------|----------|
# | `+` | Addition | `5 + 3` | `8` |
# | `-` | Subtraktion | `5 - 3` | `2` |
# | `*` | Multiplikation | `5 * 3` | `15` |
# | `/` | Division | `6 / 2` | `3.0` |
# | `**` | Potenz | `2 ** 3` | `8` |
#
# ### Beispiel:

# %%
a = 10
b = 3
summe = a + b
differenz = a - b
produkt = a * b

# %% [markdown]
# **Ergebnis:**
# - `summe` hat den Wert `13`
# - `differenz` hat den Wert `7`
# - `produkt` hat den Wert `30`
#
# ---
#
# ## 4. Funktionen – Code wiederverwenden
#
# Eine **Funktion** ist ein Stück Code, das man mehrfach aufrufen kann.
#
# ### Aufbau einer Funktion

# %%
def funktionsname():
    # Hier steht der Code
    pass

# %% [markdown]
# **Erklärung:**
# - `def` bedeutet: "Definiere eine neue Funktion"
# - `funktionsname` ist der Name, den Sie vergeben
# - `()` gehört zur Syntax (später kommen Parameter rein)
# - `:` zeigt an: "Jetzt kommt der Code der Funktion"
# - **Einrückung** (4 Leerzeichen) ist wichtig! Alles Eingerückte gehört zur Funktion
#
# ### Beispiel: Funktion ohne Parameter

# %%
def gruesse():
    print("Hallo Welt!")

# %% [markdown]
# **Funktion aufrufen:**

# %%
gruesse()

# %% [markdown]
# ### Beispiel: Funktion mit Parameter
#
# Parameter sind **Eingabewerte** für die Funktion.
# 1

# %%
def gruesse(name):
    print("Hallo " + name)

# %% [markdown]
# **Funktion aufrufen:**

# %%
gruesse("Anna")
gruesse("Max")

# %% [markdown]
# **Erklärung:**
# - `name` ist der Parameter (steht in den Klammern)
# - Beim Aufruf geben wir einen Wert mit: `"Anna"` oder `"Max"`
# - Die Funktion verwendet diesen Wert
#
# ### Beispiel: Funktion mit Rückgabewert
#
# Oft soll eine Funktion ein **Ergebnis zurückgeben**.

# %%
def addiere(a, b):
    ergebnis = a + b
    return ergebnis

# %% [markdown]
# **Erklärung:**
# - `a` und `b` sind Parameter (zwei Eingabewerte)
# - `return` bedeutet: "Gib diesen Wert zurück"
# - Wir können das Ergebnis in einer Variable speichern
#
# **Funktion aufrufen:**

# %%
summe = addiere(5, 3)
print(summe)

# %% [markdown]
# **Ausgabe:**
# ```
# 8
# ```
#
# **Was passiert hier?**
# - `addiere(5, 3)` ruft die Funktion auf
# - Die Funktion rechnet `5 + 3 = 8`
# - `return 8` gibt den Wert zurück
# - Der Wert wird in `summe` gespeichert
#
# ### Kürzer schreiben:

# %%
def addiere(a, b):
    return a + b

# %% [markdown]
# Das macht genau das Gleiche – nur kürzer.
#
# ---
#
# ## 5. Vergleiche – Bedingungen prüfen
#
# Wir wollen oft prüfen: Ist etwas gleich? Ist etwas größer?
#
# ### Vergleichsoperatoren
#
# | Operator | Bedeutung | Beispiel | Ergebnis |
# |----------|-----------|----------|----------|
# | `==` | gleich | `5 == 5` | `True` |
# | `!=` | ungleich | `5 != 3` | `True` |
# | `>` | größer | `5 > 3` | `True` |
# | `<` | kleiner | `5 < 3` | `False` |
# | `>=` | größer oder gleich | `5 >= 5` | `True` |
# | `<=` | kleiner oder gleich | `3 <= 5` | `True` |
#
# **Wichtig:**
# - `==` (zwei Gleichheitszeichen) für Vergleiche
# - `=` (ein Gleichheitszeichen) für Zuweisungen
#
# ### Beispiel:

# %%
a = 10
b = 5

print(a == b)  # False, weil 10 nicht gleich 5
print(a > b)   # True, weil 10 größer als 5
print(a != b)  # True, weil 10 ungleich 5

# %% [markdown]
# ---
#
# ## 6. if-Bedingungen – Entscheidungen treffen
#
# Mit `if` können wir Code nur unter bestimmten Bedingungen ausführen.
#
# ### Aufbau:
#
# ```python
# if bedingung:
#     # Code, der ausgeführt wird, wenn die Bedingung wahr ist
# ```
#
# ### Beispiel:

# %%
alter = 18

if alter >= 18:
    print("Du bist volljährig")

# %% [markdown]
# **Was passiert hier?**
# - Python prüft: Ist `alter >= 18`?
# - Ja → Der eingerückte Code wird ausgeführt
# - Nein → Der eingerückte Code wird übersprungen
#
# ### Beispiel mit else:

# %%
alter = 16

if alter >= 18:
    print("Du bist volljährig")
else:
    print("Du bist minderjährig")

# %% [markdown]
# ---
#
# ## 7. assert – Die Basis für Tests
#
# `assert` ist das wichtigste Werkzeug für Tests.
#
# ### Was macht assert?
#
# ```python
# assert bedingung
# ```
#
# **Verhalten:**
# - Wenn die Bedingung **wahr** ist → nichts passiert (alles gut)
# - Wenn die Bedingung **falsch** ist → Programm bricht ab mit Fehlermeldung
#
# ### Beispiel 1: Assertion erfolgreich

# %%
alter = 25
assert alter > 18
print("Test bestanden!")

# %% [markdown]
# **Erklärung:**
# - `alter > 18` ist wahr (25 ist größer als 18)
# - `assert` ist zufrieden → Code läuft weiter
#
# ### Beispiel 2: Assertion schlägt fehl

# %%
alter = 16
assert alter > 18
print("Test bestanden!")

# %% [markdown]
# **Ausgabe:**
# ```
# AssertionError
# ```
#
# **Erklärung:**
# - `alter > 18` ist falsch (16 ist nicht größer als 18)
# - `assert` schlägt fehl → Programm stoppt
# - Die Zeile `print("Test bestanden!")` wird nie erreicht
#
# ### assert mit Gleichheit

# %%
ergebnis = 2 + 3
assert ergebnis == 5
print("Rechnung korrekt!")

# %% [markdown]
# **Was passiert hier?**
# - `ergebnis` hat den Wert `5`
# - `ergebnis == 5` ist wahr
# - Test besteht ✓
#
# ### assert mit Fehlermeldung
#
# Man kann eine eigene Fehlermeldung hinzufügen:

# %%
ergebnis = 2 + 3
assert ergebnis == 6, "Erwartete 6, bekam aber " + str(ergebnis)

# %% [markdown]
# **Ausgabe:**
# ```
# AssertionError: Erwartete 6, bekam aber 5
# ```
#
# ---
#
# ## 8. Kommentare – Code dokumentieren
#
# Kommentare sind Notizen im Code, die Python ignoriert.
#
# ### Einzeiliger Kommentar:

# %%
# Das ist ein Kommentar
alter = 25  # Kommentare können auch am Ende stehen

# %% [markdown]
# ### Mehrzeiliger Kommentar:

# %%
"""
Das ist ein mehrzeiliger Kommentar.
Er kann über mehrere Zeilen gehen.
Wird für Dokumentation verwendet.
"""

# %% [markdown]
# ---
#
# ## 9. Unser erster "Test" (informell)
#
# Jetzt kombinieren wir alles zu einem ersten informellen Test.
#
# ### Szenario:
#
# Wir haben eine Funktion `addiere`, die zwei Zahlen addiert.
# Wir wollen prüfen, ob sie richtig funktioniert.
#
# ### Code:

# %%
def addiere(a, b):
    return a + b

# Unser informeller Test
ergebnis = addiere(2, 3)
assert ergebnis == 5
print("Test bestanden: addiere(2, 3) = 5")

ergebnis2 = addiere(10, 20)
assert ergebnis2 == 30
print("Test bestanden: addiere(10, 20) = 30")

# %% [markdown]
# ### Was haben wir gemacht?
#
# **AAA-Pattern:**
#
# 1. **Arrange (Vorbereiten):**
#    Die Funktion `addiere` existiert
#
# 2. **Act (Ausführen):**
#    Wir rufen `addiere(2, 3)` auf
#
# 3. **Assert (Überprüfen):**
#    Wir prüfen mit `assert`, ob das Ergebnis `5` ist
#
# ### Wenn der Test fehlschlägt:

# %%
def addiere(a, b):
    return a * b  # FEHLER: multipliziert statt addiert!

ergebnis = addiere(2, 3)
assert ergebnis == 5  # Wird fehlschlagen!

# %% [markdown]
# **Ausgabe:**
# ```
# AssertionError
# ```
#
# **Erklärung:**
# - `addiere(2, 3)` gibt `6` zurück (weil multipliziert)
# - `assert 6 == 5` schlägt fehl
# - Wir haben einen Fehler gefunden! 🐛
#
# ---
#
# ## 10. Zusammenfassung der Python-Basics
#
# **Variablen:**
# ```python
# name = "Anna"
# alter = 25
# ```
#
# **Funktionen:**
# ```python
# def addiere(a, b):
#     return a + b
# ```
#
# **Vergleiche:**
# ```python
# a == b  # gleich
# a != b  # ungleich
# a > b   # größer
# ```
#
# **Bedingungen:**
# ```python
# if alter >= 18:
#     print("volljährig")
# ```
#
# **assert (Tests):**
# ```python
# assert ergebnis == 5  # Prüft, ob wahr
# ```
#
# **Kommentare:**
# ```python
# # Das ist ein Kommentar
# ```
#
# ---
#
# ## Was Sie jetzt können
#
#  Variablen erstellen und verwenden
#  Einfache Funktionen schreiben
#  Funktionen mit Parametern und Rückgabewert
#  Werte vergleichen
#  Mit `assert` einfache Tests schreiben
#  Code mit Kommentaren dokumentieren
#
# Das ist alles, was Sie für die ersten Tests brauchen!
