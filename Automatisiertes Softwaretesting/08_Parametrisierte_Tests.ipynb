# %% [markdown]
# # Parametrisierte Tests mit pytest
#
# ## Willkommen zur Test-Effizienz! 🚀
#
# Stellen Sie sich vor: Sie möchten die ISBN-Validierung Ihrer Bibliothek testen.
#
# **Ohne Parametrisierung:**
# - 10 verschiedene ISBNs testen = 10 Test-Funktionen schreiben 😰
# - Viel Code-Duplikation
# - Schwer zu warten
#
# **Mit Parametrisierung:**
# - 10 verschiedene ISBNs testen = 1 Test-Funktion schreiben! 🎉
# - Kein duplizierter Code
# - Einfach zu erweitern
#
# ---
#
# ## Was Sie in diesem Skript lernen:
#
# 1. **`@pytest.mark.parametrize`** - Ein Test, viele Eingaben
# 2. **Äquivalenzklassen** automatisch testen
# 3. **Grenzwertanalyse** mit parametrisierten Tests
# 4. **Mehrere Parameter** gleichzeitig testen
# 5. **Test-IDs** für bessere Lesbarkeit
#
# **Das ist echte Test-Automatisierung!** ⚡

# %% [markdown]
# ---
#
# ## 1. Das Problem: Code-Duplikation in Tests
#
# ### Szenario: ISBN-Validierung testen
#
# Wir möchten verschiedene ISBN-Formate testen:
# - ✅ Gültige ISBN-13 (978-3-16-148410-0)
# - ✅ Gültige ISBN-10 (3-16-148410-X)
# - ❌ Ungültige ISBN (zu kurz, zu lang, falsche Zeichen)
#
# ### Ohne Parametrisierung (viel Code!):

# %%
# Beispiel: Tests OHNE Parametrisierung

def test_valid_isbn_1():
    """Test mit ISBN 978-3-16-148410-0"""
    isbn = "978-3-16-148410-0"
    assert len(isbn.replace("-", "")) == 13
    print(f"✅ Test bestanden für: {isbn}")

def test_valid_isbn_2():
    """Test mit ISBN 978-0-13-468599-1"""
    isbn = "978-0-13-468599-1"
    assert len(isbn.replace("-", "")) == 13
    print(f"✅ Test bestanden für: {isbn}")

def test_valid_isbn_3():
    """Test mit ISBN 978-1-23-456789-0"""
    isbn = "978-1-23-456789-0"
    assert len(isbn.replace("-", "")) == 13
    print(f"✅ Test bestanden für: {isbn}")

# Tests ausführen
test_valid_isbn_1()
test_valid_isbn_2()
test_valid_isbn_3()

print("\n🔴 Problem: Viel Code-Duplikation!")
print("   - 3 Tests = 3 Funktionen")
print("   - Gleiche Logik, nur andere Daten")
print("   - Schwer zu warten!")

# %% [markdown]
# ### 📝 Das Problem:
#
# - 🔴 **Code-Duplikation** - Die gleiche Logik wird wiederholt
# - 🔴 **Viele Funktionen** - 10 ISBNs = 10 Funktionen
# - 🔴 **Schwer zu erweitern** - Neue ISBN? Neue Funktion schreiben!
# - 🔴 **Schwer zu warten** - Logik ändern? Alle Funktionen anpassen!
#
# **Es muss einen besseren Weg geben!** 💡

# %% [markdown]
# ---
#
# ## 2. Die Lösung: `@pytest.mark.parametrize`
#
# ### Was ist Parametrisierung?
#
# **Parametrisierung** bedeutet: **Ein Test, viele Eingaben**.
#
# pytest führt den Test **automatisch mehrmals** aus - einmal für jede Eingabe!
#
# ### Syntax:
#
# ```python
# @pytest.mark.parametrize("parameter_name", [wert1, wert2, wert3])
# def test_funktion(parameter_name):
#     # Test-Logik
#     pass
# ```
#
# ### Wie funktioniert das?
#
# 1. **pytest sieht den Decorator** `@pytest.mark.parametrize`
# 2. **pytest liest die Werte** `[wert1, wert2, wert3]`
# 3. **pytest führt den Test 3x aus:**
#    - 1. Durchlauf: `parameter_name = wert1`
#    - 2. Durchlauf: `parameter_name = wert2`
#    - 3. Durchlauf: `parameter_name = wert3`
#
# **Automatisch!** 🎯

# %% [markdown]
# ---
#
# ## 3. Erstes Beispiel: ISBN-Länge testen
#
# Lassen Sie uns die obigen Tests mit Parametrisierung umschreiben:

# %%
# Beispiel: Tests MIT Parametrisierung

# Für dieses Notebook simulieren wir pytest.mark.parametrize
def parametrize_test(test_func, param_name, param_values):
    """
    Simuliert @pytest.mark.parametrize für dieses Notebook.
    
    In einem echten Projekt würden Sie schreiben:
    @pytest.mark.parametrize("isbn", [...])
    """
    print(f"\n🧪 Test: {test_func.__name__}")
    print(f"   Parameter: {param_name}")
    print(f"   Anzahl Testfälle: {len(param_values)}\n")
    
    for i, value in enumerate(param_values, 1):
        print(f"   [{i}/{len(param_values)}] Teste mit {param_name}={value}")
        test_func(value)
        print(f"       ✅ Bestanden!")


# Der parametrisierte Test
def test_isbn_length(isbn):
    """
    Test: ISBN hat die richtige Länge (13 Zeichen ohne Bindestriche).
    
    Dieser Test wird automatisch für jede ISBN ausgeführt!
    """
    # Bindestriche entfernen und Länge prüfen
    isbn_clean = isbn.replace("-", "")
    assert len(isbn_clean) == 13, f"ISBN {isbn} hat falsche Länge: {len(isbn_clean)}"


# Test-Daten: Liste von ISBNs
isbn_test_data = [
    "978-3-16-148410-0",
    "978-0-13-468599-1",
    "978-1-23-456789-0",
    "978-3-86680-192-9",
]

# Test ausführen (in echtem Projekt: pytest macht das automatisch!)
parametrize_test(test_isbn_length, "isbn", isbn_test_data)

print("\n✅ Ergebnis: 1 Test-Funktion → 4 Testfälle!")
print("   Statt 4 Funktionen zu schreiben, haben wir nur 1 geschrieben!")

# %% [markdown]
# ### 📝 Was haben wir erreicht?
#
# ✅ **1 Test-Funktion** statt 4
#
# ✅ **Keine Code-Duplikation** - Logik nur einmal geschrieben
#
# ✅ **Einfach zu erweitern** - Neue ISBN? Einfach zur Liste hinzufügen!
#
# ✅ **Einfach zu warten** - Logik ändern? Nur an einer Stelle!
#
# ---
#
# ### In einem echten Projekt:
#
# ```python
# import pytest
#
# @pytest.mark.parametrize("isbn", [
#     "978-3-16-148410-0",
#     "978-0-13-468599-1",
#     "978-1-23-456789-0",
#     "978-3-86680-192-9",
# ])
# def test_isbn_length(isbn):
#     isbn_clean = isbn.replace("-", "")
#     assert len(isbn_clean) == 13
# ```
#
# **pytest führt diesen Test automatisch 4x aus!** 🚀

# %% [markdown]
# ---
#
# ## 4. Äquivalenzklassen mit parametrisierten Tests
#
# ### Erinnerung: Was sind Äquivalenzklassen?
#
# **Äquivalenzklassen** teilen Eingaben in Gruppen:
# - ✅ **Gültige Klasse** - Eingaben, die akzeptiert werden sollten
# - ❌ **Ungültige Klassen** - Eingaben, die abgelehnt werden sollten
#
# ### Beispiel: Erscheinungsjahr eines Buches
#
# **Anforderung:** Jahr muss zwischen 1450 (Erfindung Buchdruck) und heute liegen.
#
# **Äquivalenzklassen:**
# 1. ❌ **Zu alt:** Jahr < 1450 (z.B. 1000, 1400)
# 2. ✅ **Gültig:** 1450 ≤ Jahr ≤ 2024 (z.B. 1500, 2000, 2024)
# 3. ❌ **Zukunft:** Jahr > 2024 (z.B. 2025, 3000)
#
# ### Ohne Parametrisierung:
# - 3 Äquivalenzklassen × 2 Testwerte = 6 Test-Funktionen 😰
#
# ### Mit Parametrisierung:
# - 1 Test-Funktion für gültige Werte
# - 1 Test-Funktion für ungültige Werte
# - **= 2 Test-Funktionen!** 🎉

# %%
# Unsere Book-Klasse mit Jahr-Validierung

class InvalidYearError(Exception):
    """Wird ausgelöst, wenn das Jahr ungültig ist."""
    pass


class Book:
    """
    Repräsentiert ein Buch mit Jahr-Validierung.
    """
    
    MIN_YEAR = 1450  # Erfindung des Buchdrucks
    MAX_YEAR = 2024  # Aktuelles Jahr
    
    def __init__(self, isbn, title, author, year):
        self.isbn = isbn
        self.title = title
        self.author = author
        self.year = self._validate_year(year)
    
    def _validate_year(self, year):
        """
        Validiert das Erscheinungsjahr.
        
        Args:
            year (int): Das zu validierende Jahr
        
        Returns:
            int: Das validierte Jahr
        
        Raises:
            InvalidYearError: Wenn das Jahr außerhalb des gültigen Bereichs liegt
        """
        if year < self.MIN_YEAR:
            raise InvalidYearError(f"Jahr {year} ist zu alt (min: {self.MIN_YEAR})")
        
        if year > self.MAX_YEAR:
            raise InvalidYearError(f"Jahr {year} liegt in der Zukunft (max: {self.MAX_YEAR})")
        
        return year
    
    def __str__(self):
        return f"{self.title} von {self.author} ({self.year})"


# Test: Gültiges Buch erstellen
try:
    buch = Book("978-3-16-148410-0", "Clean Code", "Robert C. Martin", 2008)
    print(f"✅ Buch erstellt: {buch}")
except InvalidYearError as e:
    print(f"❌ Fehler: {e}")

# Test: Ungültiges Jahr (zu alt)
try:
    buch = Book("978-3-16-148410-0", "Altes Buch", "Autor", 1000)
    print(f"✅ Buch erstellt: {buch}")
except InvalidYearError as e:
    print(f"❌ Fehler (erwartet): {e}")

# %% [markdown]
# ---
#
# ## 5. Parametrisierte Tests für Äquivalenzklassen

# %%
# Parametrisierte Tests für gültige Jahre

def test_valid_years(year):
    """
    Test: Bücher mit gültigen Jahren können erstellt werden.
    
    Testet die Äquivalenzklasse: 1450 ≤ Jahr ≤ 2024
    """
    book = Book("978-3-16-148410-0", "Test Book", "Test Author", year)
    assert book.year == year


# Test-Daten: Gültige Jahre (verschiedene Äquivalenzklassen-Vertreter)
valid_years = [
    1450,  # Grenzwert: Minimum
    1500,  # Frühe Neuzeit
    1800,  # 19. Jahrhundert
    2000,  # Moderne
    2024,  # Grenzwert: Maximum
]

print("🧪 Test: Gültige Jahre\n")
for i, year in enumerate(valid_years, 1):
    print(f"   [{i}/{len(valid_years)}] Teste Jahr: {year}")
    test_valid_years(year)
    print(f"       ✅ Bestanden!")

print("\n✅ Alle gültigen Jahre wurden akzeptiert!")

# %%
# Parametrisierte Tests für ungültige Jahre

def test_invalid_years(year):
    """
    Test: Bücher mit ungültigen Jahren werden abgelehnt.
    
    Testet die Äquivalenzklassen:
    - Jahr < 1450 (zu alt)
    - Jahr > 2024 (Zukunft)
    """
    try:
        book = Book("978-3-16-148410-0", "Test Book", "Test Author", year)
        # Wenn wir hier ankommen, ist der Test fehlgeschlagen!
        raise AssertionError(f"Jahr {year} sollte abgelehnt werden, wurde aber akzeptiert!")
    except InvalidYearError:
        # Das ist das erwartete Verhalten!
        pass


# Test-Daten: Ungültige Jahre
invalid_years = [
    1000,   # Mittelalter (zu alt)
    1449,   # Grenzwert: Knapp unter Minimum
    2025,   # Grenzwert: Knapp über Maximum
    3000,   # Ferne Zukunft
    -100,   # Negative Jahreszahl
]

print("🧪 Test: Ungültige Jahre\n")
for i, year in enumerate(invalid_years, 1):
    print(f"   [{i}/{len(invalid_years)}] Teste Jahr: {year}")
    test_invalid_years(year)
    print(f"       ✅ Korrekt abgelehnt!")

print("\n✅ Alle ungültigen Jahre wurden korrekt abgelehnt!")

# %% [markdown]
# ### 📝 Was haben wir getestet?
#
# ✅ **Gültige Äquivalenzklasse:**
# - 5 Testfälle mit 1 Test-Funktion
# - Grenzwerte (1450, 2024) und typische Werte (1500, 1800, 2000)
#
# ✅ **Ungültige Äquivalenzklassen:**
# - 5 Testfälle mit 1 Test-Funktion
# - Zu alt (1000, 1449), Zukunft (2025, 3000), Negativ (-100)
#
# **Gesamt: 10 Testfälle mit nur 2 Test-Funktionen!** 🎯
#
# ---
#
# ### In einem echten Projekt:
#
# ```python
# import pytest
#
# @pytest.mark.parametrize("year", [1450, 1500, 1800, 2000, 2024])
# def test_valid_years(year):
#     book = Book("978-3-16-148410-0", "Test", "Author", year)
#     assert book.year == year
#
# @pytest.mark.parametrize("year", [1000, 1449, 2025, 3000, -100])
# def test_invalid_years(year):
#     with pytest.raises(InvalidYearError):
#         Book("978-3-16-148410-0", "Test", "Author", year)
# ```
#
# **pytest führt automatisch 10 Tests aus!** 🚀

# %% [markdown]
# ---
#
# ## 6. Mehrere Parameter gleichzeitig
#
# Sie können auch **mehrere Parameter** gleichzeitig testen!
#
# ### Beispiel: ISBN und Jahr zusammen testen
#
# ```python
# @pytest.mark.parametrize("isbn, year", [
#     ("978-3-16-148410-0", 2008),
#     ("978-0-13-468599-1", 2019),
#     ("978-1-23-456789-0", 2020),
# ])
# def test_book_creation(isbn, year):
#     book = Book(isbn, "Test", "Author", year)
#     assert book.isbn == isbn
#     assert book.year == year
# ```
#
# ### Syntax:
#
# ```python
# @pytest.mark.parametrize("param1, param2", [
#     (wert1_a, wert2_a),  # Testfall 1
#     (wert1_b, wert2_b),  # Testfall 2
#     (wert1_c, wert2_c),  # Testfall 3
# ])
# ```
#
# **Jede Zeile ist ein Testfall!**

# %%
# Beispiel: Mehrere Parameter testen

def test_book_with_multiple_params(isbn, title, author, year):
    """
    Test: Buch mit verschiedenen Parametern erstellen.
    
    Testet mehrere Parameter gleichzeitig.
    """
    book = Book(isbn, title, author, year)
    
    # Alle Parameter überprüfen
    assert book.isbn == isbn
    assert book.title == title
    assert book.author == author
    assert book.year == year


# Test-Daten: Mehrere Parameter
book_test_data = [
    # (isbn, title, author, year)
    ("978-3-16-148410-0", "Clean Code", "Robert C. Martin", 2008),
    ("978-0-13-468599-1", "The Pragmatic Programmer", "Hunt & Thomas", 2019),
    ("978-0-13-235088-4", "Clean Architecture", "Robert C. Martin", 2017),
    ("978-0-13-475759-9", "Refactoring", "Martin Fowler", 2018),
]

print("🧪 Test: Bücher mit mehreren Parametern\n")
for i, (isbn, title, author, year) in enumerate(book_test_data, 1):
    print(f"   [{i}/{len(book_test_data)}] Teste: {title} ({year})")
    test_book_with_multiple_params(isbn, title, author, year)
    print(f"       ✅ Bestanden!")

print("\n✅ Alle Bücher wurden korrekt erstellt!")

# %% [markdown]
# ---
#
# ## 7. Test-IDs für bessere Lesbarkeit
#
# ### Das Problem:
#
# pytest zeigt parametrisierte Tests so an:
#
# ```
# test_book.py::test_valid_years[1450] PASSED
# test_book.py::test_valid_years[1500] PASSED
# test_book.py::test_valid_years[1800] PASSED
# ```
#
# **Was bedeutet `[1450]`?** Nicht sehr aussagekräftig! 🤔
#
# ### Die Lösung: Test-IDs
#
# ```python
# @pytest.mark.parametrize("year", [
#     pytest.param(1450, id="minimum"),
#     pytest.param(1500, id="early_modern"),
#     pytest.param(1800, id="19th_century"),
#     pytest.param(2000, id="modern"),
#     pytest.param(2024, id="maximum"),
# ])
# def test_valid_years(year):
#     book = Book("978-3-16-148410-0", "Test", "Author", year)
#     assert book.year == year
# ```
#
# **Ausgabe:**
# ```
# test_book.py::test_valid_years[minimum] PASSED
# test_book.py::test_valid_years[early_modern] PASSED
# test_book.py::test_valid_years[19th_century] PASSED
# test_book.py::test_valid_years[modern] PASSED
# test_book.py::test_valid_years[maximum] PASSED
# ```
#
# **Viel besser lesbar!** ✅

# %%
# Beispiel: Test-IDs für bessere Lesbarkeit

def test_with_ids(year, test_id):
    """
    Test mit aussagekräftigen IDs.
    """
    book = Book("978-3-16-148410-0", "Test Book", "Test Author", year)
    assert book.year == year


# Test-Daten mit IDs
year_test_data_with_ids = [
    (1450, "minimum"),
    (1500, "early_modern"),
    (1800, "19th_century"),
    (2000, "modern"),
    (2024, "maximum"),
]

print("🧪 Test: Jahre mit aussagekräftigen IDs\n")
for year, test_id in year_test_data_with_ids:
    print(f"   test_valid_years[{test_id}]")
    test_with_ids(year, test_id)
    print(f"       ✅ PASSED")

print("\n✅ Viel besser lesbar als [1450], [1500], etc.!")

# %% [markdown]
# ---
#
# ## 8. Praktisches Beispiel: Library-Tests parametrisieren
#
# Lassen Sie uns unsere Library-Klasse mit parametrisierten Tests testen:

# %%
# Library-Klasse (Wiederholung)

class BookAlreadyExistsError(Exception):
    """Wird ausgelöst, wenn ein Buch mit derselben ISBN bereits existiert."""
    pass

class BookNotFoundError(Exception):
    """Wird ausgelöst, wenn ein Buch nicht gefunden wird."""
    pass


class Library:
    """
    Verwaltet eine Sammlung von Büchern.
    """
    
    def __init__(self):
        self.books = {}
    
    def add_book(self, book):
        """Fügt ein Buch zur Bibliothek hinzu."""
        if book.isbn in self.books:
            raise BookAlreadyExistsError(f"Buch mit ISBN {book.isbn} existiert bereits!")
        self.books[book.isbn] = book
    
    def get_book(self, isbn):
        """Gibt ein Buch anhand der ISBN zurück."""
        if isbn not in self.books:
            raise BookNotFoundError(f"Buch mit ISBN {isbn} nicht gefunden!")
        return self.books[isbn]
    
    def count_books(self):
        """Gibt die Anzahl der Bücher zurück."""
        return len(self.books)

# %%
# Parametrisierte Tests für Library

def test_add_multiple_books(books_to_add):
    """
    Test: Mehrere Bücher zur Bibliothek hinzufügen.
    
    Testet verschiedene Anzahlen von Büchern.
    """
    library = Library()
    
    # Alle Bücher hinzufügen
    for book in books_to_add:
        library.add_book(book)
    
    # Anzahl überprüfen
    assert library.count_books() == len(books_to_add)
    
    # Alle Bücher abrufbar?
    for book in books_to_add:
        retrieved_book = library.get_book(book.isbn)
        assert retrieved_book == book


# Test-Daten: Verschiedene Anzahlen von Büchern
library_test_data = [
    # 1 Buch
    [
        Book("978-3-16-148410-0", "Clean Code", "Robert C. Martin", 2008),
    ],
    # 2 Bücher
    [
        Book("978-3-16-148410-0", "Clean Code", "Robert C. Martin", 2008),
        Book("978-0-13-468599-1", "The Pragmatic Programmer", "Hunt & Thomas", 2019),
    ],
    # 5 Bücher
    [
        Book("978-3-16-148410-0", "Clean Code", "Robert C. Martin", 2008),
        Book("978-0-13-468599-1", "The Pragmatic Programmer", "Hunt & Thomas", 2019),
        Book("978-0-13-235088-4", "Clean Architecture", "Robert C. Martin", 2017),
        Book("978-0-13-475759-9", "Refactoring", "Martin Fowler", 2018),
        Book("978-0-13-468599-2", "Design Patterns", "Gang of Four", 1994),
    ],
]

print("🧪 Test: Verschiedene Anzahlen von Büchern hinzufügen\n")
for i, books in enumerate(library_test_data, 1):
    print(f"   [{i}/{len(library_test_data)}] Teste mit {len(books)} Buch/Büchern")
    test_add_multiple_books(books)
    print(f"       ✅ Bestanden!")

print("\n✅ Alle Tests bestanden!")
print("   1 Test-Funktion → 3 Testfälle (1, 2, 5 Bücher)")

# %% [markdown]
# ---
#
# ## 9. Zusammenfassung
#
# ### Was haben Sie gelernt?
#
# ✅ **`@pytest.mark.parametrize`** - Ein Test, viele Eingaben
# - Reduziert Code-Duplikation massiv
# - Einfach zu erweitern und zu warten
# - pytest führt Tests automatisch mehrfach aus
#
# ✅ **Äquivalenzklassen testen**
# - Gültige und ungültige Klassen systematisch testen
# - Grenzwerte und typische Werte abdecken
# - Wenige Test-Funktionen, viele Testfälle
#
# ✅ **Mehrere Parameter**
# - Kombinationen von Parametern testen
# - Tuple-Syntax: `(param1, param2)`
#
# ✅ **Test-IDs**
# - Bessere Lesbarkeit der Test-Reports
# - `pytest.param(wert, id="name")`
#
# ---
#
# ### Vorher vs. Nachher:
#
# | Ohne Parametrisierung | Mit Parametrisierung |
# |----------------------|---------------------|
# | 10 ISBNs = 10 Funktionen | 10 ISBNs = 1 Funktion |
# | Viel Code-Duplikation | Keine Duplikation |
# | Schwer zu erweitern | Einfach zu erweitern |
# | Schwer zu warten | Einfach zu warten |
#
# ---
#
# ### Die wichtigsten Syntax-Formen:
#
# ```python
# # Ein Parameter
# @pytest.mark.parametrize("param", [wert1, wert2, wert3])
#
# # Mehrere Parameter
# @pytest.mark.parametrize("param1, param2", [
#     (wert1_a, wert2_a),
#     (wert1_b, wert2_b),
# ])
#
# # Mit Test-IDs
# @pytest.mark.parametrize("param", [
#     pytest.param(wert1, id="name1"),
#     pytest.param(wert2, id="name2"),
# ])
# ```
#
# **Parametrisierung ist ein Kern-Feature der Test-Automatisierung!** 🎯

# %% [markdown]
# ---
#
# ## 10. Praktische Übungen
#
# ### Übung 1: ISBN-Validierung parametrisieren
#
# Erweitern Sie die `Book`-Klasse um eine ISBN-Validierung:
# - ISBN-13 muss genau 13 Ziffern haben (ohne Bindestriche)
# - ISBN-10 muss genau 10 Zeichen haben (ohne Bindestriche)
#
# Schreiben Sie parametrisierte Tests für:
# - ✅ Gültige ISBN-13 (mindestens 3 Beispiele)
# - ✅ Gültige ISBN-10 (mindestens 3 Beispiele)
# - ❌ Ungültige ISBNs (zu kurz, zu lang, falsche Zeichen)
#
# ---
#
# ### Übung 2: Autor-Namen testen
#
# Schreiben Sie parametrisierte Tests für Autor-Namen:
#
# **Äquivalenzklassen:**
# - ✅ Gültig: "Robert C. Martin", "Martin Fowler", "Gang of Four"
# - ❌ Ungültig: "", "   ", "123", "@#$%"
#
# Verwenden Sie `@pytest.mark.parametrize` mit Test-IDs!
#
# ---
#
# ### Übung 3: Mehrere Parameter kombinieren
#
# Schreiben Sie einen parametrisierten Test, der **ISBN, Titel, Autor und Jahr** gleichzeitig testet.
#
# Erstellen Sie mindestens 5 verschiedene Testfälle mit realistischen Buchdaten.
#
# ---
#
# ### Übung 4: Library-Suche parametrisieren
#
# Erweitern Sie die `Library`-Klasse um eine Suchfunktion:
#
# ```python
# def search_by_title(self, search_term):
#     """Sucht Bücher nach Titel (Teilstring-Suche)."""
#     results = []
#     for book in self.books.values():
#         if search_term.lower() in book.title.lower():
#             results.append(book)
#     return results
# ```
#
# Schreiben Sie parametrisierte Tests für:
# - Verschiedene Suchbegriffe
# - Groß-/Kleinschreibung
# - Teilstrings
# - Keine Treffer
#
# ---
#
# ### Übung 5: Grenzwertanalyse
#
# Testen Sie die Grenzwerte für das Erscheinungsjahr:
#
# **Grenzwerte:**
# - 1449 (ungültig)
# - 1450 (gültig)
# - 2024 (gültig)
# - 2025 (ungültig)
#
# Verwenden Sie parametrisierte Tests mit aussagekräftigen Test-IDs:
# - `"below_minimum"`
# - `"at_minimum"`
# - `"at_maximum"`
# - `"above_maximum"`

# %% [markdown]
# ---
#
# ## 🎉 Herzlichen Glückwunsch!
#
# Sie haben **parametrisierte Tests** gemeistert!
#
# Sie können jetzt:
# - ✅ `@pytest.mark.parametrize` verwenden
# - ✅ Äquivalenzklassen systematisch testen
# - ✅ Grenzwerte automatisch testen
# - ✅ Mehrere Parameter kombinieren
# - ✅ Test-IDs für bessere Lesbarkeit verwenden
#
# **Das ist ein riesiger Schritt in Richtung professioneller Test-Automatisierung!** 🚀
#
# ---
#
# ## Ausblick: Was kommt als Nächstes?
#
# Im nächsten Skript lernen Sie:
#
# ### 📊 Test-Coverage
# - Wie viel Code wird von Tests abgedeckt?
# - Coverage-Reports interpretieren
# - Ungetesteten Code finden
# - Ziel: >80% Coverage erreichen
#
# **Bis bald!** 👋
