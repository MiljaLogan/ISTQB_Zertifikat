# %%
def test_create_empty_library():
    p

# %%
<b>Marcel Döbbel</b>
class Library:
    def __init__(self):
        """erstellt leere Bibliothek"""
        self._books = {}

    def book_count(self):
        """gibt die Anzahl der Bücher zurück"""
        return len(self._books)

# %%
<b>Marcel Döbbel</b>
class Library:
    def __init__(self):
        """erstellt leere Bibliothek"""
        self._books = {}

    def book_count(self):
        """gibt die Anzahl der Bücher zurück"""
        return len(self._books)

    def add_book(self, book):
        """Fügt ein Buch zur Bibliothek hinzu"""
        self._books[book.isbn] = book

# %%
<b>Marcel Döbbel</b>
def test_add_book():
    """Prüft ob ein Buch zur Library hinzugefügt wird"""
    #Arrange
    library = Library()
    book1 = Book("Test_1", 12345678910, "Max Muster")
    book2 = Book("Test_2", 12345678911, "Max Muster")

    #Act
    library.add_book(book1)
    library.add_book(book2)

    #Assert
    assert library.book_count() == 2, "Library sollte jetzt 1 Buch haben"

# %% [markdown]
# <b>Marcel Döbbel</b>
# python faker

# %%
<b>Marcel Döbbel</b>
def test_get_book():
    "Test: Buch über ISBN abrufen"

    #Arrange
    library = Library()
    book = Book("Test_1", 12345678910, "Max Muster")
    library.add_book(book)

    #Act
    retrieved_book = library.get_book(12345678910)

    #Assert
    assert retrieved_book is not None, "Buch sollte gefunden werden"
    assert retrieved_book.title == "Test_1"
    assert retrieved_book.isbn == 12345678910

# %%
<b>Marcel Döbbel</b>
class Library:
    def __init__(self):
        """erstellt leere Bibliothek"""
        self._books = {}

    def book_count(self):
        """gibt die Anzahl der Bücher zurück"""
        return len(self._books)

    def add_book(self, book):
        """Fügt ein Buch zur Bibliothek hinzu"""
        self._books[book.isbn] = book

    def get_book(self, isbn):
        """Gibt ein Buch anhand der ISBN zurück"""
        return self._books.get(isbn)
