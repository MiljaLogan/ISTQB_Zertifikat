# %% [markdown]
# ###  **1. CamelCase (auch „Upper Camel Case“)**
#
# * **Verwendung:** Klassennamen in Python
# * **Merkmal:** Jedes Wort beginnt mit einem Großbuchstaben, **kein Trennzeichen**
# * **Beispiel:** `MeineKlasse`, `AutoFabrik`, `BenutzerProfil`
#
# ---
#
# ###  **2. snake\_case**
#
# * **Verwendung:** Variablen, Funktionen in Python
# * **Merkmal:** Alle Buchstaben **klein**, Wörter werden durch **Unterstriche** getrennt
# * **Beispiel:** `mein_name`, `berechne_durchschnitt`, `ist_gültig`
#
# ---
#
# ###  **3. lowerCamelCase (auch „camelCase“)**
#
# * **Verwendung:** In JavaScript oder Java bei Variablen und Methoden üblich
# * **Merkmal:** Erstes Wort klein, **alle weiteren Wörter groß beginnen**, **kein Trennzeichen**
# * **Beispiel:** `meinName`, `benutzerEingabe`, `ladeDaten`
#
# ---
#
# ###  **4. UPPER\_SNAKE\_CASE**
#
# * **Verwendung:** Konstante Werte (also unveränderliche Variablen)
# * **Merkmal:** **Nur Großbuchstaben**, mit **Unterstrichen**
# * **Beispiel:** `MAX_GESCHWINDIGKEIT`, `STANDARD_FARBE`, `PI_WERT`
#
# ---
#
# ###  **5. kebab-case** (nicht in Python erlaubt!)
#
# * **Verwendung:** In URLs oder bestimmten Konfigurationsformaten (z. B. YAML), **nicht** in Python!
# * **Merkmal:** Wörter durch **Bindestriche getrennt**
# * **Beispiel:** `mein-name`, `daten-laden`
# * **Problem:** In Python **SyntaxError**, da `-` als Rechenzeichen interpretiert wird!
#
# ---
#
# ### 🧠 **Zusammenfassung (Python-spezifisch)**
#
# | Zweck     | Empfehlung in Python | Beispiel           |
# | --------- | -------------------- | ------------------ |
# | Variable  | `snake_case`         | `benutzer_name`    |
# | Funktion  | `snake_case`         | `zeige_ergebnis()` |
# | Klasse    | `CamelCase`          | `BenutzerProfil`   |
# | Konstante | `UPPER_SNAKE_CASE`   | `STANDARD_WERT`    |
#
# ---
