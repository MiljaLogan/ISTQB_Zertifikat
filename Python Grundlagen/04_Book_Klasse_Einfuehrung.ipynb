# %% [markdown]
# # Objektorientierte Programmierung: Die Book-Klasse
#
# ## 🎯 Lernziele
#
# Nach dieser Unterrichtseinheit können Sie:
# - Erklären, was eine Klasse ist und wozu sie dient
# - Den Unterschied zwischen Klasse und Objekt verstehen
# - Eine einfache Klasse mit Attributen erstellen
# - Tests für Klassen schreiben (TDD!)
# - Die `__init__`-Methode (Konstruktor) verwenden

# %% [markdown]
# ---
#
# ## 1. Warum brauchen wir eine Book-Klasse?
#
# ### Das Problem ohne Klassen
#
# Stellen Sie sich vor, wir wollen Informationen über Bücher speichern. Ohne Klassen könnten wir das so machen:

# %%
# Buch 1
buch1_titel = "Der kleine Prinz"
buch1_isbn = "9783140464109"
buch1_autor = "Antoine de Saint-Exupéry"

# Buch 2
buch2_titel = "Hamlet"
buch2_isbn = "9783150000014"
buch2_autor = "William Shakespeare"

print(f"Buch 1: {buch1_titel} von {buch1_autor}")
print(f"Buch 2: {buch2_titel} von {buch2_autor}")

# %% [markdown]
# **Probleme:**
# - ❌ Unübersichtlich bei vielen Büchern
# - ❌ Keine Struktur: Welche Variablen gehören zusammen?
# - ❌ Fehleranfällig: Was, wenn wir `buch1_autor` vergessen?
# - ❌ Schwer zu erweitern: Neue Eigenschaften für alle Bücher hinzufügen?
#
# ### Die Lösung: Eine Book-Klasse
#
# Mit einer Klasse können wir einen **Bauplan** für Bücher erstellen:

# %%
# Bauplan definieren
class Book:
    def __init__(self, title, isbn, author):
        self.title = title
        self.isbn = isbn
        self.author = author

# Konkrete Bücher nach diesem Bauplan erstellen
buch1 = Book("Der kleine Prinz", "9783140464109", "Antoine de Saint-Exupéry")
buch2 = Book("Hamlet", "9783150000014", "William Shakespeare")

print(f"Buch 1: {buch1.title} von {buch1.author}")
print(f"Buch 2: {buch2.title} von {buch2.author}")

# %% [markdown]
# **Vorteile:**
# - ✅ Übersichtlich und strukturiert
# - ✅ Alle Informationen eines Buches gehören zusammen
# - ✅ Wiederverwendbar: Beliebig viele Bücher nach gleichem Muster
# - ✅ Erweiterbar: Neue Eigenschaften zentral hinzufügen

# %% [markdown]
# ---
#
# ## 2. Was ist eine Klasse? Was ist ein Objekt?
#
# ### Die Bauplan-Metapher
#
# Stellen Sie sich vor, Sie wollen Häuser bauen:
#
# #### **Klasse = Bauplan**
# - Der Bauplan beschreibt, **wie** ein Haus aussehen soll
# - Er definiert: Wie viele Zimmer? Welche Farbe? Wie groß?
# - Der Bauplan selbst ist **kein Haus**, sondern nur die Anleitung
#
# #### **Objekt = Konkretes Haus**
# - Nach dem Bauplan können Sie **viele Häuser** bauen
# - Jedes Haus ist ein **Objekt** (eine konkrete Ausführung des Bauplans)
# - Alle Häuser folgen dem gleichen Bauplan, können aber unterschiedliche Werte haben
#
# ### Übertragen auf unsere Book-Klasse

# %%
# KLASSE = Bauplan für Bücher
class Book:
    def __init__(self, title, isbn, author):
        self.title = title
        self.isbn = isbn
        self.author = author

# OBJEKTE = Konkrete Bücher nach diesem Bauplan
buch1 = Book("Python Testing", "9781234567890", "Max Mustermann")
buch2 = Book("Clean Code", "9780987654321", "Robert C. Martin")
buch3 = Book("TDD by Example", "9781111111111", "Kent Beck")

print(f"Buch 1: {buch1.title}")
print(f"Buch 2: {buch2.title}")
print(f"Buch 3: {buch3.title}")

# %% [markdown]
# - `class Book:` → Der **Bauplan** (Klasse)
# - `buch1`, `buch2`, `buch3` → **Konkrete Bücher** (Objekte)

# %% [markdown]
# ---
#
# ## 3. Anatomie einer Klasse: Die Bestandteile
#
# ### 3.1 Die Klassen-Definition
#
# ```python
# class Book:
#     # Hier kommt der Inhalt der Klasse
# ```
#
# - `class` → Schlüsselwort: "Ich definiere jetzt eine Klasse"
# - `Book` → Name der Klasse (immer mit **Großbuchstaben** beginnen!)
# - `:` → Doppelpunkt leitet den Klassen-Körper ein
#
# **Namenskonvention:**
# - Klassen: `Book`, `Library`, `User` (CamelCase, Großbuchstabe am Anfang)
# - Objekte: `buch1`, `meine_library` (snake_case, Kleinbuchstaben)

# %% [markdown]
# ### 3.2 Der Konstruktor: `__init__`
#
# #### Was ist `__init__`?
#
# - `__init__` ist eine **spezielle Methode** (Konstruktor)
# - Sie wird **automatisch aufgerufen**, wenn ein neues Objekt erstellt wird
# - Sie **initialisiert** das Objekt (setzt die Startwerte)

# %%
class Book:
    def __init__(self, title, isbn, author):
        # Diese Methode wird automatisch aufgerufen!
        print(f"Ein neues Buch wird erstellt: {title}")
        self.title = title
        self.isbn = isbn
        self.author = author

# Beim Erstellen wird __init__ automatisch aufgerufen
buch = Book("Python Testing", "ISBN-123", "Max Mustermann")

# %% [markdown]
# #### Was bedeutet `self`?
#
# `self` ist eine Referenz auf das **aktuelle Objekt**.
#
# **Analogie:** Stellen Sie sich vor, Sie füllen ein Formular aus:
# - Das Formular ist die Klasse (Bauplan)
# - `self` ist **Ihr konkretes Formular** (Ihr Objekt)
# - `self.title = title` bedeutet: "Schreibe den Titel in **mein** Formular"

# %%
class Book:
    def __init__(self, title, isbn, author):
        # self = das aktuelle Objekt (z.B. buch1)
        self.title = title    # Setze den Titel für DIESES Objekt
        self.isbn = isbn      # Setze die ISBN für DIESES Objekt
        self.author = author  # Setze den Autor für DIESES Objekt

buch1 = Book("Python Testing", "ISBN-123", "Max")
# Intern passiert:
# self = buch1 (das neue Objekt)
# self.title = "Python Testing"  → buch1.title = "Python Testing"
# self.isbn = "ISBN-123"         → buch1.isbn = "ISBN-123"
# self.author = "Max"            → buch1.author = "Max"

print(f"Titel: {buch1.title}")
print(f"ISBN: {buch1.isbn}")
print(f"Autor: {buch1.author}")

# %% [markdown]
# ### 3.3 Attribute (Eigenschaften)
#
# - **Attribute** sind die **Eigenschaften** eines Objekts
# - Sie speichern die **Daten** des Objekts
# - Jedes Objekt hat seine **eigenen** Attributwerte

# %%
class Book:
    def __init__(self, title, isbn, author):
        self.title = title    # Attribut
        self.isbn = isbn      # Attribut
        self.author = author  # Attribut

# Zwei verschiedene Objekte mit verschiedenen Attributwerten
buch1 = Book("Buch A", "ISBN-001", "Autor A")
buch2 = Book("Buch B", "ISBN-002", "Autor B")

print(f"Buch 1 Titel: {buch1.title}")  # Ausgabe: Buch A
print(f"Buch 2 Titel: {buch2.title}")  # Ausgabe: Buch B

# buch1 und buch2 sind unabhängig voneinander!
buch1.title = "Neuer Titel für Buch 1"
print(f"Buch 1 Titel: {buch1.title}")  # Ausgabe: Neuer Titel für Buch 1
print(f"Buch 2 Titel: {buch2.title}")  # Ausgabe: Buch B (unverändert!)

# %% [markdown]
# ---
#
# ## 4. Wie funktioniert das Erstellen eines Objekts?
#
# ### Schritt-für-Schritt: Was passiert bei `buch = Book("Python", "ISBN-123", "Max")`?

# %%
class Book:
    def __init__(self, title, isbn, author):
        print("Schritt 3: __init__ wird aufgerufen")
        print(f"  - title Parameter: {title}")
        print(f"  - isbn Parameter: {isbn}")
        print(f"  - author Parameter: {author}")
        
        print("Schritt 4: Attribute werden gesetzt")
        self.title = title
        self.isbn = isbn
        self.author = author
        print("  - self.title =", self.title)
        print("  - self.isbn =", self.isbn)
        print("  - self.author =", self.author)

print("Schritt 1: Python sieht Book(...)")
print("Schritt 2: Python erstellt ein neues, leeres Objekt")
buch = Book("Python Testing", "ISBN-123", "Max Mustermann")
print("Schritt 5: Das fertige Objekt wird in 'buch' gespeichert")
print(f"\nErgebnis: buch.title = {buch.title}")

# %% [markdown]
# **Zusammenfassung der Schritte:**
#
# 1. Python sieht `Book(...)` und sucht die Klasse `Book`
# 2. Python erstellt ein **neues, leeres Objekt** im Speicher
# 3. Python ruft **automatisch** `__init__` auf
# 4. Die Attribute werden gesetzt
# 5. Das fertige Objekt wird zurückgegeben und in `buch` gespeichert

# %% [markdown]
# ---
#
# ## 5. Warum starten wir mit Book?
#
# ### Unsere Bibliotheksverwaltung: Der große Plan
#
# Wir entwickeln über die nächsten Tage eine **Bibliotheksverwaltung**. Dafür brauchen wir verschiedene "Dinge":
#
# 1. **Bücher** (Book) ← **Hier starten wir!**
# 2. **Bibliothek** (Library) - verwaltet viele Bücher
# 3. **Benutzer** (User) - können Bücher ausleihen
# 4. **Ausleihen** (Loan) - wer hat was ausgeliehen?
#
# ### Warum zuerst Book?
#
# - ✅ **Einfach:** Ein Buch hat nur ein paar Eigenschaften (Titel, ISBN, Autor)
# - ✅ **Verständlich:** Jeder kennt Bücher aus dem Alltag
# - ✅ **Grundlage:** Ohne Bücher keine Bibliothek!
# - ✅ **Lernfreundlich:** Perfekt, um Klassen zu verstehen
#
# **Prinzip:** Vom Einfachen zum Komplexen!

# %% [markdown]
# ---
#
# ## 6. TDD: Test-First für unsere Book-Klasse
#
# ### Erinnerung: Der TDD-Zyklus
#
# 1. **RED:** Test schreiben → Test schlägt fehl (Code existiert noch nicht)
# 2. **GREEN:** Minimalen Code schreiben → Test läuft
# 3. **REFACTOR:** Code verbessern (Tests bleiben grün)
#
# ### Unser Plan für Book
#
# **Schritt 1:** Test schreiben - "Ich will ein Book-Objekt erstellen können"
# - Test schlägt fehl (Book existiert noch nicht) ❌
#
# **Schritt 2:** Book-Klasse implementieren (nur das Nötigste!)
# - Test läuft ✅
#
# **Schritt 3:** Weitere Tests schreiben
# - Attribute auslesen
# - Mehrere Bücher erstellen
#
# ### Los geht's: Unser erster Test!

# %%
# SCHRITT 1: Test schreiben (RED - Test wird fehlschlagen)

# Wir testen OHNE pytest, um es einfach zu halten
# Später verwenden wir pytest!

def test_book_creation():
    """Test: Ich kann ein Book-Objekt erstellen"""
    # Arrange (Vorbereiten)
    title = "Python Testing"
    isbn = "9781234567890"
    author = "Max Mustermann"
    
    # Act (Ausführen)
    book = Book(title, isbn, author)
    
    # Assert (Überprüfen)
    assert book.title == title, f"Erwartet: {title}, Bekommen: {book.title}"
    assert book.isbn == isbn, f"Erwartet: {isbn}, Bekommen: {book.isbn}"
    assert book.author == author, f"Erwartet: {author}, Bekommen: {book.author}"
    
    print("✅ Test bestanden: Book-Objekt wurde korrekt erstellt!")

# Test ausführen
test_book_creation()

# %% [markdown]
# **Was passiert hier?**
#
# 1. **Arrange:** Wir bereiten die Testdaten vor (Titel, ISBN, Autor)
# 2. **Act:** Wir führen die Aktion aus (Book-Objekt erstellen)
# 3. **Assert:** Wir überprüfen, ob alles korrekt ist
#
# Der Test läuft jetzt, weil wir die Book-Klasse bereits definiert haben! ✅

# %% [markdown]
# ### Weitere Tests: Mehrere Bücher erstellen

# %%
def test_multiple_books_are_independent():
    """Test: Mehrere Book-Objekte sind unabhängig voneinander"""
    # Arrange & Act
    book1 = Book("Buch A", "ISBN-001", "Autor A")
    book2 = Book("Buch B", "ISBN-002", "Autor B")
    
    # Assert
    assert book1.title == "Buch A", "Buch 1 hat falschen Titel"
    assert book2.title == "Buch B", "Buch 2 hat falschen Titel"
    
    # Ändere book1 - book2 sollte unverändert bleiben
    book1.title = "Geänderter Titel"
    assert book1.title == "Geänderter Titel", "Buch 1 wurde nicht geändert"
    assert book2.title == "Buch B", "Buch 2 wurde fälschlicherweise geändert!"
    
    print("✅ Test bestanden: Bücher sind unabhängig voneinander!")

# Test ausführen
test_multiple_books_are_independent()

# %% [markdown]
# ---
#
# ## 7. Zusammenfassung: Die wichtigsten Konzepte
#
# ### Klasse vs. Objekt
#
# | Klasse | Objekt |
# |--------|--------|
# | Bauplan | Konkretes Exemplar |
# | Wird **einmal** definiert | Kann **beliebig oft** erstellt werden |
# | `class Book:` | `buch1 = Book(...)` |
# | Beschreibt **wie** etwas aussieht | **Ist** etwas Konkretes |
#
# ### Die Bestandteile einer Klasse
#
# ```python
# class Book:                              # Klassen-Definition
#     def __init__(self, title, isbn, author):  # Konstruktor
#         self.title = title               # Attribut
#         self.isbn = isbn                 # Attribut
#         self.author = author             # Attribut
# ```
#
# - **`class Book:`** → Definiert den Bauplan
# - **`__init__`** → Konstruktor (wird automatisch aufgerufen)
# - **`self`** → Referenz auf das aktuelle Objekt
# - **Attribute** → Eigenschaften des Objekts (Daten)
#
# ### Warum Klassen?
#
# - ✅ **Struktur:** Zusammengehörige Daten gruppieren
# - ✅ **Wiederverwendbarkeit:** Bauplan für viele Objekte
# - ✅ **Wartbarkeit:** Änderungen zentral an einer Stelle
# - ✅ **Realitätsnähe:** Modelliert echte "Dinge" (Bücher, Benutzer, ...)

# %% [markdown]
# ---
#
# ## 8. Praktische Übungen
#
# ### Übung 1: Eigene Bücher erstellen
#
# Erstellen Sie drei Book-Objekte mit Ihren Lieblingsbüchern und geben Sie die Titel aus.

# %%
# Ihre Lösung hier:
# buch1 = Book(...)
# buch2 = Book(...)
# buch3 = Book(...)

# %% [markdown]
# ### Übung 2: Attribute ändern
#
# Erstellen Sie ein Book-Objekt und ändern Sie nachträglich den Titel. Geben Sie den Titel vor und nach der Änderung aus.

# %%
# Ihre Lösung hier:

# %% [markdown]
# ### Übung 3: Test schreiben
#
# Schreiben Sie einen Test, der überprüft, dass ein Book-Objekt die ISBN korrekt speichert.

# %%
def test_book_stores_isbn_correctly():
    """Test: Book speichert ISBN korrekt"""
    # Ihre Lösung hier:
    pass

# Test ausführen
# test_book_stores_isbn_correctly()

# %% [markdown]
# ---
#
# ## 9. Ausblick: Was kommt als Nächstes?
#
# ### Heute: Einfache Book-Klasse
# - Nur Attribute (Datencontainer)
# - Keine Validierung
# - Keine Methoden
#
# ### Später erweitern wir Book:
# - **Validierung:** ISBN prüfen (ist sie gültig?)
# - **Methoden:** `__str__()` für schöne Ausgabe
# - **Logik:** Buch als "ausgeliehen" markieren
#
# ### Dann bauen wir die Library-Klasse:
# - Verwaltet viele Book-Objekte
# - Bücher hinzufügen, suchen, löschen
# - Duplikate verhindern
#
# **Prinzip:** Schritt für Schritt, immer mit Tests! 🚀

# %% [markdown]
# ---
#
# ## 🎓 Wichtige Begriffe
#
# | Begriff | Bedeutung | Beispiel |
# |---------|-----------|----------|
# | **Klasse** | Bauplan für Objekte | `class Book:` |
# | **Objekt** | Konkrete Instanz einer Klasse | `buch1 = Book(...)` |
# | **Konstruktor** | Methode zum Initialisieren (`__init__`) | `def __init__(self, ...):` |
# | **self** | Referenz auf das aktuelle Objekt | `self.title = title` |
# | **Attribut** | Eigenschaft eines Objekts | `self.title`, `self.isbn` |
# | **Instanz** | Anderes Wort für Objekt | `buch1` ist eine Instanz von `Book` |

# %% [markdown]
# ---
#
# ## ✅ Selbsttest: Haben Sie es verstanden?
#
# Beantworten Sie für sich:
#
# 1. Was ist der Unterschied zwischen einer Klasse und einem Objekt?
# 2. Wozu dient `__init__`?
# 3. Was bedeutet `self`?
# 4. Wie viele Objekte kann ich von einer Klasse erstellen?
# 5. Warum starten wir mit der Book-Klasse?
#
# **Antworten:**
# 1. Klasse = Bauplan, Objekt = konkretes Exemplar nach diesem Bauplan
# 2. `__init__` initialisiert ein neues Objekt (setzt Startwerte)
# 3. `self` ist eine Referenz auf das aktuelle Objekt
# 4. Beliebig viele!
# 5. Weil sie einfach, verständlich und die Grundlage für unsere Bibliothek ist

# %% [markdown]
# ---
#
# ## 🎉 Herzlichen Glückwunsch!
#
# Sie haben die Grundlagen der objektorientierten Programmierung mit der Book-Klasse gelernt!
#
# **Nächste Schritte:**
# - Lösen Sie die Übungen
# - Experimentieren Sie mit der Book-Klasse
# - Im nächsten Skript: Die Library-Klasse und pytest!
